# %% [markdown]
# this notebook  analyse my personal code
# read a text file
# show all the activities
# count total lines and words

# %% [markdown]
# Python Program: View Folder and Files
# To display the current folder and list all files in it.

# %%
file_name = "mymorning_routine.txt"

with open(file_name, "r") as file:
    lines = file.readlines()

print("Total lines:", len(lines))
# Out:
# Total lines: 17

# %%
for line in lines:
    print(line.strip())
# Out:
# Wake up at 6:00 AM
# Drink a glass of water
# Morning walk for 20 minutes
# Breakfast with coffee
# i do drawing
# then i practice singing
# i cook Lunch
# i have my lunch
# Watch movie for some time
# I call and talk to my parents and sibling
# I take some rest
# I read novel for 30 minutes
# evening walk for 30 minutes
# I cook dinner
# I have dinner
# again i do walk for 10 minutes
# Sleep at 10:00 PM

# %%
word_count = 0

for line in lines:
    words = line.split()
    word_count += len(words)

print("Total number of words:", word_count)
# Out:
# Total number of words: 78

# %% [markdown]
# Count Words in a File
# To count the total number of words in a given text.
# python
# word_count = 0
#
# for line in lines:
#     words = line.split()
#     word_count += len(words) with the help of AI

# %%
from collections import Counter

all_words = []

for line in lines:
    words = line.lower().split()
    all_words.extend(words)

word_freq = Counter(all_words)

print("Most common words:")
for word, count in word_freq.most_common(5):
    print(word, ":", count)
# Out:
# Most common words:
# i : 10
# for : 5
# minutes : 4
# walk : 3
# at : 2

# %% [markdown]
# i searched in chatgpt how to fine most common words in python
# then it shows
#
# ## Code
# ```python
# from collections import Counter
#
# for line in lines:
#     words = line.lower().split()
#     all_words.extend(words)
#
# word_freq = Counter(all_words)
#
# print("Most common words:")
#     print(word, ":", count)
