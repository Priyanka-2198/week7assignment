# %%
# start with input 
income1 = float(input("enter the first income"));
income2 = float(input("enter the second income"));
expense = float(input("enter the expense"))

# adding the income1 and income 2 
total_income = income1+ income2

#show the expense  
balance = total_income - expense
#print all the transaction
print("\n transaction summary", )
print("income1 :", income1)
print("income2 =", income2)
print ("Expense =", expense)
print ("Total Income =", total_income)
print ("final balance =", balance)

# %% [markdown]
# firstly we searched it in Ai to create a from of psuedo and it gave me simplecode of psudo like
# Start
# input income 1
# input income 2
# and total = income 1 + income 2
# the we analyse and under stand
# furthemore i typed convere this prgram into pyhton it give me all the code and analyse  and understand all the prgram and typed it in google collab but its nit working then we add it in visual studio.
